# %%
from pprint import pprint

from calculus_core.decourt_quaresma import calcular_decourt_quaresma
from calculus_core.models import PerfilSPT
from calculus_core.utils import calcular_capacidade_estaca

perfil_spt = PerfilSPT()
perfil_spt.adicionar_medidas(
    [
        (1, 3, 'areia_argilosa'),
        (2, 3, 'areia_argilosa'),
        (3, 5, 'areia_argilosa'),
        (4, 6, 'argila_arenosa'),
        (5, 8, 'argila_arenosa'),
        (6, 13, 'argila_arenosa'),
        (7, 17, 'argila_arenosa'),
        (8, 25, 'argila_arenosa'),
        (9, 27, 'argila_areno_siltosa'),
        (10, 32, 'argila_areno_siltosa'),
        (11, 36, 'argila_areno_siltosa'),
    ]
)
resultado = calcular_capacidade_estaca(
    calcular_decourt_quaresma,
    perfil_spt,
    tipo_estaca='pré-moldada',
    processo_construcao='deslocamento',
    formato='quadrada',
    secao_transversal=0.3,
)
pprint(resultado, sort_dicts=False)
# Out:
# [{'cota': 1,
#   'resistencia_ponta': 108.0,
#   'resistencia_lateral': 12.0,
#   'resistencia_lateral_total': 12.0,
#   'capacidade_total': 120.0},
#  {'cota': 2,
#   'resistencia_ponta': 131.99999999999997,
#   'resistencia_lateral': 24.0,
#   'resistencia_lateral_total': 24.0,
#   'capacidade_total': 155.99999999999997},
#  {'cota': 3,
#   'resistencia_ponta': 168.0,
#   'resistencia_lateral': 72.0,
#   'resistencia_lateral_total': 72.0,
#   'capacidade_total': 240.0},
#  {'cota': 4,
#   'resistencia_ponta': 68.39999999999999,
#   'resistencia_lateral': 96.0,
#   'resistencia_lateral_total': 96.0,
#   'capacidade_total': 164.39999999999998},
#  {'cota': 5,
#   'resistencia_ponta': 97.2,
#   'resistencia_lateral': 133.33333333333331,
#   'resistencia_lateral_total': 133.33333333333331,
#   'capacidade_total': 230.5333333333333},
#  {'cota': 6,
#   'resistencia_ponta': 136.79999999999998,
#   'resistencia_lateral': 174.00000000000003,
#   'resistencia_lateral_total': 174.00000000000003,
#   'capacidade_total': 310.8},
#  {'cota': 7,
#   'resistencia_ponta': 198.0,
#   'resistencia_lateral': 224.00000000000006,
#   'resistencia_lateral_total': 224.00000000000006,
#   'capacidade_total': 422.00000000000006},
#  {'cota': 8,
#   'resistencia_ponta': 248.39999999999998,
#   'resistencia_lateral': 298.66666666666663,
#   'resistencia_lateral_total': 298.66666666666663,
#   'capacidade_total': 547.0666666666666},
#  {'cota': 9,
#   'resistencia_ponta': 302.4,
#   'resistencia_lateral': 390.85714285714283,
#   'resistencia_lateral_total': 390.85714285714283,
#   'capacidade_total': 693.2571428571428},
#  {'cota': 10,
#   'resistencia_ponta': 342.0,
#   'resistencia_lateral': 520.0000000000001,
#   'resistencia_lateral_total': 520.0000000000001,
#   'capacidade_total': 862.0000000000001},
#  {'cota': 11,
#   'resistencia_ponta': 424.8,
#   'resistencia_lateral': 655.1111111111111,
#   'resistencia_lateral_total': 655.1111111111111,
#   'capacidade_total': 1079.911111111111}]
